# %%
# !pip install evaluate sacrebleu rouge-score
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.8 MB 4.8 MB/s eta 0:00:01
#    ------------------- -------------------- 1.8/3.8 MB 4.4 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 4.8 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 4.4 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=25025 sha256=a88c62f51c53b6e3d9448d34f5d0ae85ba483f8cf6668f4c1f279fab5788735a
#   Stored in directory: c:\users\krish\appdata\local\pip\cache\wheels\85\9d\af\01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\utils\_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File c:\Users\krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/meta-llama/Meta-Llama-3-2B/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...
